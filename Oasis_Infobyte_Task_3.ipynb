# %%
import zipfile
import pandas as pd

# Mount Google Drive

# Path to your uploaded zip file in Google Drive
zip_path = "c:\\Users\\Harshada\\Downloads\\archive (13).zip"

# Extract zip
with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall("/content/airbnb")

# Load CSV inside extracted folder
df = pd.read_csv("/content/airbnb/AB_NYC_2019.csv")

# Quick look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#Data integration
# Shape
print("Shape:", df.shape)

# Column data types
print(df.dtypes)

# Summary statistics
df.describe(include="all")
# Out:
# Shape: (48895, 16)
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# ...

# %%
#step 3-Handelling missing values
# Check missing values
df.isnull().sum()

# Fill missing numerical column with median
df["reviews_per_month"] = df["reviews_per_month"].fillna(df["reviews_per_month"].median())

# Fill missing text column with "Unknown"
df["name"] = df["name"].fillna("Unknown")

# Verify again
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#step 4- removing duplicates
# Count duplicates
print("Duplicates before:", df.duplicated().sum())

# Drop duplicates
df = df.drop_duplicates()

print("Duplicates after:", df.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %%
#step 5- standardization
# Make column names lowercase
df.columns = df.columns.str.lower()

# Strip extra spaces in text columns
df["neighbourhood_group"] = df["neighbourhood_group"].str.strip()

# Keep only non-negative prices
df = df[df["price"] >= 0]

# %%
# Outliers detection
import matplotlib.pyplot as plt

# Boxplot for price
plt.figure(figsize=(8,5))
plt.boxplot(df["price"])
plt.title("Price Outliers")
plt.show()

# Remove extreme outliers (e.g. > 1000)
df = df[df["price"] < 1000]

# Boxplot again after cleaning
plt.figure(figsize=(8,5))
plt.boxplot(df["price"])
plt.title("Price After Removing Outliers")
plt.show()
